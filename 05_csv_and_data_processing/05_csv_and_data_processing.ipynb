# %% [markdown]
# <a href="https://colab.research.google.com/github/nietbaeviysa/python-basics/blob/main/05_csv_and_data_processing/05_csv_and_data_processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
data = [
    {"Name": "Ethan", "Score": 75, "City": "Bukhara"},
    {"Name": "Bob", "Score": 68, "City": "Nukus"}
]
with open ("student.csv", "w", newline="", encoding="utf-8") as file:
  fieldnames = ["Name", "Score", "City"]
  writer = csv.DictWriter(file, fieldnames=fieldnames)

  writer.writeheader()
  writer.writerows(data)

print("student.csv created successfully!")



import csv
total_score = 0
count = 0

with open ("student.csv", "r", encoding="utf-8") as file:
  reader = csv.DictReader(file)
  print("-- list of students from CSV --")
  for row in reader:
    name = row["Name"]
    score = int(row["Score"])
    city = row["City"]

    total_score += score
    count += 1
    print(f"Student: {name} point: {score} City: {city}")


  average_score = total_score / count
  print(f"\nAverage score: {average_score:.1f}")
# Out:
# student.csv created successfully!
# -- list of students from CSV --
# Student: Ethan point: 75 City: Bukhara
# Student: Bob point: 68 City: Nukus
#
# Average score: 71.5
